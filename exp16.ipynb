# %% [markdown]
# <a href="https://colab.research.google.com/github/challa-sravya-26/DSA0301-NLP/blob/main/exp16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Named Entity Recognition Using spaCy

# %%
# !pip install spacy -q
# !python -m spacy download en_core_web_sm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 99.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = """
Sundar Pichai is the CEO of Google.
Google is headquartered in California.
He visited India in 2024.
"""

doc = nlp(text)

print("Named Entities:")
print("----------------")

for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# Named Entities:
# ----------------
# Sundar Pichai -> PERSON
# Google -> ORG
# Google -> ORG
# California -> GPE
# India -> GPE
# 2024 -> DATE
