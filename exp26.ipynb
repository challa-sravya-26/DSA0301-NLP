# %% [markdown]
# <a href="https://colab.research.google.com/github/challa-sravya-26/DSA0301-NLP/blob/main/exp26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Machine Translation Using Hugging Face Transformers

# %%
# !pip install -q transformers sentencepiece torch

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Model name
model_name = "Helsinki-NLP/opus-mt-en-fr"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load translation model
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# English input
text = "Natural language processing is very useful."

# Tokenize the input
inputs = tokenizer(
    text,
    return_tensors="pt"
)

# Generate French translation
outputs = model.generate(
    **inputs,
    max_new_tokens=100
)

# Decode the output
translation = tokenizer.decode(
    outputs[0],
    skip_special_tokens=True
)

print("English:")
print(text)

print("\nFrench:")
print(translation)
# Out:
# /usr/local/lib/python3.13/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=512) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# English:
# Natural language processing is very useful.
#
# French:
# Le traitement du langage naturel est très utile.
