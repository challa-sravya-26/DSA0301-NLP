# %% [markdown]
# <a href="https://colab.research.google.com/github/challa-sravya-26/DSA0301-NLP/blob/main/exp7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# POS Tagging Using NLTK

# %%
# !pip install nltk -q

import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.tokenize import word_tokenize

text = "The intelligent student solved the difficult problem quickly."

words = word_tokenize(text)

tags = nltk.pos_tag(words)

print("Word -> POS Tag")
print("----------------")

for word, tag in tags:
    print(word, "->", tag)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# Word -> POS Tag
# ----------------
# The -> DT
# intelligent -> JJ
# student -> NN
# solved -> VBD
# the -> DT
# difficult -> JJ
# problem -> NN
# quickly -> RB
# . -> .
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
